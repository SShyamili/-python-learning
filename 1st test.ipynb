# %%
import os
os.environ['GEMIN_API_KEY']='Enter the Api key'

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMIN_API_KEY'])

# %%
model=genai.GenerativeModel('gemini-2.0-flash-exp')

# %%
response=model.generate_content("What is the lifespan of a person")
print(response.text)
# Out:
# The lifespan of a person is a complex question with no single, definitive answer. Here's a breakdown of different perspectives and factors that influence it:
#
# **1. Life Expectancy:**
#
# *   **Definition:** This is the *average* number of years a person is expected to live, based on current mortality rates in a specific population. It's a statistical measure.
# *   **Global Average:** Currently, the global average life expectancy is around **73 years** (as of 2019, before the full impact of COVID-19).  This number varies significantly by country.
# *   **Factors Influencing Life Expectancy (in a specific country/region):**
#     *   **Healthcare Access and Quality:** Availability of doctors, hospitals, vaccines, treatments, and preventative care.
#     *   **Nutrition and Sanitation:** Access to clean water, nutritious food, and proper sewage disposal.
#     *   **Environmental Factors:** Air quality, pollution levels, exposure to toxins.
# ...

# %%
import pathlib
import textwrap
import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown
def to_markdown(text):
    text=text.replace('*',' *')
    return Markdown(textwrap.indent(text,'> ',predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# ...

# %%
import PIL
img=PIL.Image.open(r"C:\Users\S SHYAMILI\OneDrive\Pictures\pngtree-panda-bear-is-sitting-on-a-tree-branch-in-a-forest-image_2906332.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x359>

# %%
model=genai.GenerativeModel('models/gemini-1.5-pro-latest')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-pro-latest',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response=model.generate_content(img)
to_markdown(response.text)
# Out:
# > The image is a stylized illustration of a giant panda cub. It is sitting on a thick, horizontal branch with its paws draped over it.  The panda has the characteristic black and white fur, a pink tongue, and large, dark eyes that convey a gentle and curious expression. The background is a blurred forest scene with various shades of green, implying bamboo and other foliage. Sunlight filters through the trees, creating a warm and peaceful atmosphere. The style of the image is smooth and slightly cartoonish, focusing on the panda's cuteness.

# %%
model=genai.GenerativeModel('models/gemini-2.0-flash-exp-image-generation')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.0-flash-exp-image-generation',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response=model.generate_content(img)
to_markdown(response.text)
# Out:
# > Here are the bounding box detections:
# > ```json
# > [
# >   {"box_2d": [148, 275, 824, 734], "label": "panda"}
# > ]
# > ```

# %%
model=genai.GenerativeModel('models/gemini-1.5-flash-latest')
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-1.5-flash-latest',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %%
response=model.generate_content(img)
to_markdown(response.text)
# Out:
# > Here is a description of the image:
# >
# > Close-up view of a cartoon panda bear sitting on a log in a lush green forest.
# >
# >
# > Here's a breakdown of the image's elements:
# >
# >  *  * *The Panda: * * The panda is the central focus, taking up a significant portion of the frame. It's depicted in a cute, stylized manner with large, expressive eyes, a fluffy body, and a generally friendly demeanor. Its fur is rendered with shading to give it a three-dimensional appearance.
# >
# >  *  * *The Setting: * * The background is a blurry but detailed forest scene with tall trees and various shades of green foliage. The lighting suggests a soft, diffused sunlight filtering through the trees. The log the panda sits on is a dark brown, providing contrast to the panda's lighter fur.
# >
# ...
